# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.5 MB 991.0 kB/s eta 0:00:11
#    ---------------------------------------- 0.1/10.5 MB 544.7 kB/s eta 0:00:20
#     --------------------------------------- 0.1/10.5 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.1/10.5 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.2/10.5 MB 1.0 MB/s eta 0:00:11
#     --------------------------------------- 0.3/10.5 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/10.5 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/10.5 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/10.5 MB 776.5 kB/s eta 0:00:14
#    - -------------------------------------- 0.4/10.5 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/10.5 MB 894.8 kB/s eta 0:00:12
# ...

# %% [markdown]
# DataFrame

# %%
import numpy as np

# %%
import pandas as pd

# %%
# try to craete a dataframe
user_data = {
    "MarksA":np.random.randint(1,100,5),
    "MarksB":np.random.randint(50,100,5),
    "MarksC":np.random.randint(1,100,5)
}

# %%
user_data
# Out:
# {'MarksA': array([95, 64, 39, 29, 16]),
#  'MarksB': array([51, 55, 64, 72, 69]),
#  'MarksC': array([46,  3, 97, 10, 21])}

# %%
df = pd.DataFrame(user_data, dtype='float32')
print(df)
# Out:
#    MarksA  MarksB  MarksC
# 0    95.0    51.0    46.0
# 1    64.0    55.0     3.0
# 2    39.0    64.0    97.0
# 3    29.0    72.0    10.0
# 4    16.0    69.0    21.0

# %%
df.head(n=3)
# Out:
#    MarksA  MarksB  MarksC
# 0    95.0    51.0    46.0
# 1    64.0    55.0     3.0
# 2    39.0    64.0    97.0

# %%
df.columns
# Out:
# Index(['MarksA', 'MarksB', 'MarksC'], dtype='object')

# %%
print(df.columns)
# Out:
# Index(['MarksA', 'MarksB', 'MarksC'], dtype='object')

# %%
df.to_csv('studentMarks.csv')

# %%
mydata = pd.read_csv('studentMarks.csv')
mydata = mydata.drop(columns=['Unnamed: 0'])
print(mydata)
# Out:
#    MarksA  MarksB  MarksC
# 0    95.0    51.0    46.0
# 1    64.0    55.0     3.0
# 2    39.0    64.0    97.0
# 3    29.0    72.0    10.0
# 4    16.0    69.0    21.0

# %%
mydata.describe()
# Out:
#           MarksA     MarksB     MarksC
# count   5.000000   5.000000   5.000000
# mean   48.600000  62.200000  35.400000
# std    31.341666   8.983318  38.109054
# min    16.000000  51.000000   3.000000
# 25%    29.000000  55.000000  10.000000

# %%
mydata.tail(n=3)
# Out:
#    MarksA  MarksB  MarksC
# 2    39.0    64.0    97.0
# 3    29.0    72.0    10.0
# 4    16.0    69.0    21.0

# %%
df.iloc[3]
# Out:
# MarksA    29.0
# MarksB    72.0
# MarksC    10.0
# Name: 3, dtype: float32

# %%
df.iloc[3,0]
# Out:
# 29.0

# %%
df.iloc[3,1]
# Out:
# 72.0

# %%
idx = [df.columns.get_loc('MarksB'),df.columns.get_loc('MarksC')]
print(idx)
print(df.iloc[3,idx])
# Out:
# [1, 2]
# MarksB    72.0
# MarksC    10.0
# Name: 3, dtype: float32

# %%
df.iloc[:3, [1,2]]
# Out:
#    MarksB  MarksC
# 0    51.0    46.0
# 1    55.0     3.0
# 2    64.0    97.0

# %%
df.iloc[:3, [1,2]]
# Out:
#    MarksB  MarksC
# 0    51.0    46.0
# 1    55.0     3.0
# 2    64.0    97.0

# %%
#sorting of the data values
mydata
# Out:
#    MarksA  MarksB  MarksC
# 0    95.0    51.0    46.0
# 1    64.0    55.0     3.0
# 2    39.0    64.0    97.0
# 3    29.0    72.0    10.0
# 4    16.0    69.0    21.0

# %%
mydata.sort_values(by=['MarksC'], ascending = False)
# Out:
#    MarksA  MarksB  MarksC
# 2    39.0    64.0    97.0
# 0    95.0    51.0    46.0
# 4    16.0    69.0    21.0
# 3    29.0    72.0    10.0
# 1    64.0    55.0     3.0

# %%
data_value = mydata.values

# %%
print(type(mydata))
print(mydata.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (5, 3)

# %%
data_value
# Out:
# array([[95., 51., 46.],
#        [64., 55.,  3.],
#        [39., 64., 97.],
#        [29., 72., 10.],
#        [16., 69., 21.]])

# %%
print(type(data_value))
print(data_value.shape)
# Out:
# <class 'numpy.ndarray'>
# (5, 3)

# %%
data_value[2][2]
# Out:
# 97.0

# %% [markdown]
# # convert our numpy to dataframe

# %%
new_df = pd.DataFrame(data_value, dtype = 'int32', columns=['Physics', 'Chemistry', 'Maths'])

# %%
new_df.head()
# Out:
#    Physics  Chemistry  Maths
# 0       95         51     46
# 1       64         55      3
# 2       39         64     97
# 3       29         72     10
# 4       16         69     21

# %%
new_df.to_csv('Subject.csv', index = False)

# %%
print(new_df)
# Out:
#    Physics  Chemistry  Maths
# 0       95         51     46
# 1       64         55      3
# 2       39         64     97
# 3       29         72     10
# 4       16         69     21

# %%
pcm = pd.read_csv('Subject.csv')

# %%
print(pcm)
# Out:
#    Physics  Chemistry  Maths
# 0       95         51     46
# 1       64         55      3
# 2       39         64     97
# 3       29         72     10
# 4       16         69     21
